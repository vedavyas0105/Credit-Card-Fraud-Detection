# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_csv('../Datasets/creditcard.csv')

# %% [markdown]
# ## Exploring the Dataset

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# The dataset is highly imbalanced, making it challenging for the Machine Learning model to accurately identify fraudulent data.
#
# Here,
#
# 0 ----> Legit Transaction
#
# 1 ----> Fraud Transaction

# %% [markdown]
# ### Separating the Data for Analysis

# %%
legit = df[df['Class']==0]

# %%
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284315 rows x 31 columns]

# %%
legit['Class'].value_counts()
# Out:
# Class
# 0    284315
# Name: count, dtype: int64

# %%
fraud = df[df['Class']==1]

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 541    -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623     0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 4920    0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 6108   -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 6329    1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 541     0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623    -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920   -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108   -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329   -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
# ...          ...       ...       ...       ...       ...     ...    ...
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [492 rows x 31 columns]

# %%
fraud['Class'].value_counts()
# Out:
# Class
# 1    492
# Name: count, dtype: int64

# %% [markdown]
# ### Statistical Measures of the Data

# %%
legit["Amount"].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# The mean value of Fraud data is more than Legit data

# %% [markdown]
# ### Comparing values of both transaction types

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Under Sampling
#
# We will build a sample dataset containing distribution of Normal transactions and Fraudulent transactions
#
# The number of Normal Transactions: 284315
#
# The number of Fraudulant Transactions: 492

# %% [markdown]
# We will randomly select 492 transactions from the normal transactions and combine them with all fraudulent transactions, resulting in a balanced dataset of 492 normal and 492 fraudulent transactions.

# %%
legit_sample = legit.sample(n=492)

# %%
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148862   90265.0  1.729933 -1.653311 -0.773886 -1.632008 -1.381941 -1.040844
# 242035  151304.0  0.087255  0.936303 -0.565227 -0.156631  0.773987 -1.366834
# 11893    20478.0 -0.534639  0.462400  2.614235  1.118064 -0.596837  1.599259
# 15403    26790.0 -0.510225  0.181672  1.449477 -1.939204  0.559337 -0.697591
# 119539   75486.0 -3.513324  1.896098  0.601442 -1.631377 -3.052883 -0.477448
# ...          ...       ...       ...       ...       ...       ...       ...
# 281677  170350.0 -0.148823  1.038218  1.938359  3.097934  1.259168  1.598648
# 107947   70690.0 -1.142025  1.518889  0.836469  0.658066 -0.046930 -0.569060
# 131934   79796.0 -1.520662  1.085022  1.720737  0.620109 -1.013583  1.431759
# 238617  149744.0 -2.286697 -0.175666  0.646327  1.111830  0.496260 -0.468410
# 226787  144801.0  1.981957 -1.394153 -0.765448 -1.070490 -0.917932  0.245121
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 148862 -0.445591 -0.443636  2.205671  ... -0.752708 -1.629852  0.287511
# 242035  0.978950 -0.253406  0.048382  ...  0.266814  0.962572 -0.159725
# 11893   1.436459 -0.510462  2.145376  ... -0.544727 -0.287960 -0.055235
# 15403   0.982108 -0.572913 -1.737282  ...  0.274250  1.008818 -0.432498
# 119539 -2.280466  2.462487 -0.876494  ... -0.028606  0.077921  0.074130
# ...          ...       ...       ...  ...       ...       ...       ...
# 281677  0.851670 -0.434445 -0.747486  ...  0.113990  0.914500 -0.233434
# 107947  0.494765  0.261603 -0.408308  ...  0.077044  0.571575 -0.045704
# 131934 -0.764612  1.142216  0.308905  ...  0.168465  0.710057 -0.382529
# 238617  1.927941 -0.792196 -0.330078  ...  0.041371  0.901526  0.020175
# 226787 -1.211431  0.184084  0.005177  ...  0.462681  1.083514  0.042312
#
#              V24       V25       V26       V27       V28  Amount  Class
# 148862 -0.035015 -0.570053 -0.728893 -0.011889 -0.000043  235.77      0
# 242035 -0.183094 -0.300983 -0.131824  0.378202  0.192406   19.50      0
# 11893   0.179379 -0.590695 -0.791150 -0.433968 -0.588619  195.87      0
# 15403   0.277243  0.255431 -0.306282 -0.381809 -0.381949   15.00      0
# 119539  0.412670  0.214519  1.094080  0.084692  0.033503   17.50      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 281677  0.038539 -0.698946  0.027108 -0.512512 -0.460831   19.96      0
# 107947  0.329845 -0.103342 -0.347258  0.337747  0.069302    5.64      0
# 131934 -0.624408  0.480698  0.778289 -0.366999 -0.081271   51.12      0
# 238617  0.009146  1.095028 -0.179925 -0.920017  0.658070  170.00      0
# 226787  0.239064 -0.228098 -0.092823 -0.011927 -0.039411   99.00      0
#
# [492 rows x 31 columns]

# %% [markdown]
# ## Making Dataset for Model
#
# Now, we are concatenating both datasets to create the final dataset for the machine learning model.

# %%
final_df = pd.concat([legit_sample, fraud], axis=0)

# %%
final_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148862   90265.0  1.729933 -1.653311 -0.773886 -1.632008 -1.381941 -1.040844
# 242035  151304.0  0.087255  0.936303 -0.565227 -0.156631  0.773987 -1.366834
# 11893    20478.0 -0.534639  0.462400  2.614235  1.118064 -0.596837  1.599259
# 15403    26790.0 -0.510225  0.181672  1.449477 -1.939204  0.559337 -0.697591
# 119539   75486.0 -3.513324  1.896098  0.601442 -1.631377 -3.052883 -0.477448
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 148862 -0.445591 -0.443636  2.205671  ... -0.752708 -1.629852  0.287511
# 242035  0.978950 -0.253406  0.048382  ...  0.266814  0.962572 -0.159725
# 11893   1.436459 -0.510462  2.145376  ... -0.544727 -0.287960 -0.055235
# 15403   0.982108 -0.572913 -1.737282  ...  0.274250  1.008818 -0.432498
# 119539 -2.280466  2.462487 -0.876494  ... -0.028606  0.077921  0.074130
#
#              V24       V25       V26       V27       V28  Amount  Class
# 148862 -0.035015 -0.570053 -0.728893 -0.011889 -0.000043  235.77      0
# 242035 -0.183094 -0.300983 -0.131824  0.378202  0.192406   19.50      0
# 11893   0.179379 -0.590695 -0.791150 -0.433968 -0.588619  195.87      0
# 15403   0.277243  0.255431 -0.306282 -0.381809 -0.381949   15.00      0
# 119539  0.412670  0.214519  1.094080  0.084692  0.033503   17.50      0
#
# [5 rows x 31 columns]

# %%
final_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
final_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95904.154472  0.020406 -0.002107  0.018263 -0.070979  0.029407
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.071915  0.032069  0.054924  0.010342  ...  0.017698  0.026622
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.030017 -0.017399  0.013122  0.018208 -0.026361 -0.007721  0.005109
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       87.084980
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Splitting the Dataset into Features and Targets

# %%
X = final_df.drop('Class', axis=1)
y = final_df['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 148862   90265.0  1.729933 -1.653311 -0.773886 -1.632008 -1.381941 -1.040844
# 242035  151304.0  0.087255  0.936303 -0.565227 -0.156631  0.773987 -1.366834
# 11893    20478.0 -0.534639  0.462400  2.614235  1.118064 -0.596837  1.599259
# 15403    26790.0 -0.510225  0.181672  1.449477 -1.939204  0.559337 -0.697591
# 119539   75486.0 -3.513324  1.896098  0.601442 -1.631377 -3.052883 -0.477448
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 148862 -0.445591 -0.443636  2.205671  ... -0.113556 -0.752708 -1.629852
# 242035  0.978950 -0.253406  0.048382  ...  0.079050  0.266814  0.962572
# 11893   1.436459 -0.510462  2.145376  ... -0.085373 -0.544727 -0.287960
# 15403   0.982108 -0.572913 -1.737282  ...  0.146398  0.274250  1.008818
# 119539 -2.280466  2.462487 -0.876494  ... -0.372509 -0.028606  0.077921
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 148862  0.287511 -0.035015 -0.570053 -0.728893 -0.011889 -0.000043  235.77
# 242035 -0.159725 -0.183094 -0.300983 -0.131824  0.378202  0.192406   19.50
# 11893  -0.055235  0.179379 -0.590695 -0.791150 -0.433968 -0.588619  195.87
# 15403  -0.432498  0.277243  0.255431 -0.306282 -0.381809 -0.381949   15.00
# 119539  0.074130  0.412670  0.214519  1.094080  0.084692  0.033503   17.50
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [984 rows x 30 columns]

# %%
y
# Out:
# 148862    0
# 242035    0
# 11893     0
# 15403     0
# 119539    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# ## Splitting the Dataset into Train and Test Set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 51076    44781.0   0.985292  -0.830089   0.884408  0.154661  -1.182220
# 72075    54555.0  -0.359481   0.840725   1.494872 -0.071883   0.182615
# 56703    47545.0   1.176716   0.557091  -0.490800  0.756424   0.249192
# 150684   93888.0 -10.040631   6.139183 -12.972972  7.740555  -8.684705
# 6882      8808.0  -4.617217   1.695694  -3.114372  4.328199  -1.873257
# ...          ...        ...        ...        ...       ...        ...
# 39183    39729.0  -0.964567  -1.643541  -0.187727  1.158253  -2.458336
# 124079   77167.0  -0.600042   0.991636   1.475234  1.219278  -0.021259
# 143335   85285.0  -6.713407   3.921104  -9.746678  5.148263  -5.151563
# 260772  159719.0   0.112084   0.653549   0.034644  0.142639   0.513051
# 17317    28625.0 -27.848181  15.598193 -28.923756  6.418442 -20.346228
#
#               V6         V7         V8        V9  ...       V20       V21  \
# 51076   0.134619  -0.691562   0.253159  1.115972  ...  0.092944 -0.151564
# 72075  -0.295729   0.668200   0.053743 -0.326617  ...  0.086969 -0.234139
# 56703  -0.781871   0.228750  -0.040840 -0.432111  ... -0.102772 -0.062166
# 150684 -3.837429 -11.907702   5.833273 -5.731054  ... -0.082275  2.823431
# 6882   -0.989908  -4.577265   0.472216  0.472017  ... -0.039046  0.481830
# ...          ...        ...        ...       ...  ...       ...       ...
# 39183   0.852222   2.785163  -0.303609  0.940006  ...  1.784449  0.447180
# 124079  0.288774   0.521252   0.238261 -0.373411  ...  0.056139  0.032559
# 143335 -2.099389  -5.937767   3.578780 -4.684952  ...  0.135711  0.954272
# 260772 -1.942439   1.243326  -0.602037 -0.045956  ...  0.072108  0.351159
# 17317  -4.828202 -19.210896  18.329406 -3.668735  ...  1.697856  1.802149
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 51076  -0.502946 -0.054900  0.048391  0.075525  0.938123 -0.064902  0.017014
# 72075  -0.507943  0.019473  0.135883 -0.359467  0.047320  0.084075 -0.138646
# 56703  -0.128168 -0.040176  0.110040  0.437891  0.368809 -0.018287  0.031173
# 150684  1.153005 -0.567343  0.843012  0.549938  0.113892 -0.307375  0.061631
# 6882    0.146023  0.117039 -0.217565 -0.138776 -0.424453 -1.002041  0.890780
# ...          ...       ...       ...       ...       ...       ...       ...
# 39183   0.536204  1.634061  0.203839  0.218749 -0.221886 -0.308555 -0.164500
# 124079  0.349684 -0.126904  0.213338 -0.189138 -0.262659  0.295254  0.189485
# 143335 -0.451086  0.127214 -0.339450  0.394096  1.075295  1.649906 -0.394905
# 260772  1.200959 -0.009702  0.857300 -0.507096 -0.244059 -0.035774 -0.075245
# 17317  -2.062934 -1.269843  0.165409  1.999499 -0.211059  1.324809  0.388090
#
#         Amount
# 51076   115.00
# 72075     9.99
# 56703     0.76
# 150684    1.00
# 6882      1.10
# ...        ...
# 39183   776.83
# 124079   25.77
# 143335  252.92
# 260772   42.81
# 17317    99.99
#
# [787 rows x 30 columns]

# %%
X_test
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 230076  146179.0 -0.067672  4.251181 -6.540388  7.283657  0.513541 -2.635066
# 262826  160665.0 -0.417340  4.700055 -7.521767  7.671884  0.260821 -2.646693
# 82146    59262.0 -1.686325 -0.346521  2.654900  0.500239 -0.037830  0.954406
# 30314    35866.0 -2.044489  3.368306 -3.937111  5.623120 -3.079232 -1.253474
# 132133   79867.0 -0.808640  1.072073  1.664690 -0.691667  0.711321  0.008134
# ...          ...       ...       ...       ...       ...       ...       ...
# 118681   75172.0  1.000749 -0.146698  1.256358  1.177664 -0.865325  0.236922
# 6472      7740.0  1.023874  2.001485 -4.769752  3.819195 -1.271754 -1.734662
# 163165  115706.0  0.042798  1.015239  0.290874  2.024714  0.888001 -0.571756
# 52466    45463.0 -1.476893  2.122314 -1.229470  1.201849 -0.343264 -1.317704
# 74907    55808.0 -0.588184  0.584420  1.948566  1.324833 -0.107065  1.391636
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 230076 -1.865911  0.780272 -3.868248  ...  0.519404  0.415437 -0.469938
# 262826 -2.854432  0.958783 -4.588536  ...  0.832035  0.622200 -0.437708
# 82146  -0.231928  0.565852 -0.141528  ... -0.071708  0.409950  1.202793
# 30314  -5.778880  1.707428 -4.467103  ...  1.112028  1.483594  0.834311
# 132133  0.831335  0.144671 -1.027914  ... -0.003095 -0.163695 -0.552942
# ...          ...       ...       ...  ...       ...       ...       ...
# 118681 -0.679140  0.327079  0.276361  ... -0.102815  0.213098  0.534712
# 6472   -3.059245  0.889805  0.415382  ...  0.204138  0.343283 -0.054196
# 163165  1.265778 -0.545343 -0.689023  ...  0.144699  0.107245  0.728123
# 52466  -1.528142 -0.620953 -1.213040  ...  0.276893  1.186036 -0.040215
# 74907   0.051278  0.503063  0.039140  ... -0.103519  0.113645  0.663260
#
#              V23       V24       V25       V26       V27       V28  Amount
# 230076  0.007128 -0.388147 -0.493398  0.466468  0.566370  0.262990    0.77
# 262826 -0.090358 -0.742802 -0.312361  0.502575  0.821390  0.372379    0.77
# 82146   0.168883 -0.297814  0.197980 -0.174568  0.053898  0.103683  108.30
# 30314  -0.148486  0.001669 -0.038996  0.389526  1.300236  0.549940    7.61
# 132133 -0.210904 -0.335261  0.196877  0.039012  0.008660  0.058008    9.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 118681  0.008863  0.198004  0.175440 -0.363510  0.064216  0.034536   45.00
# 6472    0.709654 -0.372216 -2.032068  0.366778  0.395171  0.020206    1.00
# 163165 -0.249438  0.011154 -0.122129 -0.127560 -0.069335 -0.045601    7.80
# 52466  -0.238930  0.110144  0.045418 -0.569232  0.481019 -0.047555    1.00
# 74907  -0.140918 -0.268409 -0.338090 -0.184120  0.116115  0.120454   38.00
#
# [197 rows x 30 columns]

# %% [markdown]
# ## Model Training

# %% [markdown]
# We are using Logistic Regression Model

# %%
model = LogisticRegression(max_iter=200)

# %% [markdown]
# The number of maximum iterations has been increased to 200, as the model was not converging with the default value(100).

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# We are evalutaing the model based on Accuracy Score

# %%
train_predictions = model.predict(X_train)

# %%
print(accuracy_score(train_predictions, y_train))
# Out:
# 0.9275730622617535

# %%
predictions = model.predict(X_test)

# %%
print(accuracy_score(y_test, predictions))
# Out:
# 0.9644670050761421

# %% [markdown]
# The training accuracy is similar to the test accuracy, suggesting that the model is not overfitting.
